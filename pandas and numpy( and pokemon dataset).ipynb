# 1    0.285652  0.315828  0.417478  0.464472  0.525057
# 2    0.335136  0.240157  0.139917  0.126058  0.619240
# 3    0.710725  0.515872  0.316908  0.395333  0.787279
# 4    0.068904  0.223079  0.538056  0.047428  0.583037
# ..        ...       ...       ...       ...       ...
# 329  0.303704  0.042306  0.354418  0.747414  0.309633
# 330  0.325176  0.619976  0.267919  0.103217  0.031351
# 331  0.367693  0.106144  0.757074  0.160146  0.887906
# 332  0.338221  0.801101  0.226089  0.316483  0.843311
# 333  0.245002  0.398008  0.877605  0.193264  0.137597
#
# [334 rows x 5 columns]

# %%
df2 = df

# %%
df.loc[0,0] = 210

# %%
df.head(2)
# Out:
#           0         1         2         3         4
# 0       210  0.878973  0.629611  0.312773  0.158220
# 1  0.285652  0.315828  0.417478  0.464472  0.525057

# %%
df.columns = list("ABCDE")

# %%
df.head()
# Out:
#           A         B         C         D         E
# 0       210  0.878973  0.629611  0.312773  0.158220
# 1  0.285652  0.315828  0.417478  0.464472  0.525057
# 2  0.335136  0.240157  0.139917  0.126058  0.619240
# 3  0.710725  0.515872  0.316908  0.395333  0.787279
# 4  0.068904  0.223079  0.538056  0.047428  0.583037

# %%
df.loc[0,'A'] = 2101

# %%
df.head()
# Out:
#           A         B         C         D         E
# 0      2101  0.878973  0.629611  0.312773  0.158220
# 1  0.285652  0.315828  0.417478  0.464472  0.525057
# 2  0.335136  0.240157  0.139917  0.126058  0.619240
# 3  0.710725  0.515872  0.316908  0.395333  0.787279
# 4  0.068904  0.223079  0.538056  0.047428  0.583037

# %%
df = df.drop([0],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e456eed6d4af> in <module>
# ----> 1 df = df.drop([0],axis=1)
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#           A         B         C         D         E
# 0      2101  0.878973  0.629611  0.312773  0.158220
# 1  0.285652  0.315828  0.417478  0.464472  0.525057
# 2  0.335136  0.240157  0.139917  0.126058  0.619240
# 3  0.710725  0.515872  0.316908  0.395333  0.787279
# 4  0.068904  0.223079  0.538056  0.047428  0.583037

# %%
df.loc[(df['A']<0.3) & (df['C']>0.1)]
# Out:
#              A         B         C         D         E
# 1     0.285652  0.315828  0.417478  0.464472  0.525057
# 4     0.068904  0.223079  0.538056  0.047428  0.583037
# 8     0.100045  0.734523  0.346377  0.208540  0.391873
# 11     0.21441  0.384124  0.506217  0.567950  0.659563
# 16   0.0468807  0.416188  0.311461  0.851801  0.795443
# ..         ...       ...       ...       ...       ...
# 322  0.0849574  0.247073  0.252496  0.989859  0.414307
# 323  0.0921728  0.865261  0.895741  0.047788  0.442567
# 326   0.212146  0.291031  0.853202  0.254399  0.000406
# 328  0.0100322  0.896170  0.847421  0.647742  0.227288
# 333   0.245002  0.398008  0.877605  0.193264  0.137597
#
# [103 rows x 5 columns]

# %%
df.head(2)
# Out:
#           A         B         C         D         E
# 0      2101  0.878973  0.629611  0.312773  0.158220
# 1  0.285652  0.315828  0.417478  0.464472  0.525057

# %%
df.iloc[0,4]
# Out:
# 0.15821955505057916

# %%
df.iloc[[0,5], [1,2]]
# Out:
#           B         C
# 0  0.878973  0.629611
# 5  0.732171  0.546427

# %%
df.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.285652  0.315828  0.417478  0.464472  0.525057
# 2    0.335136  0.240157  0.139917  0.126058  0.619240
# 3    0.710725  0.515872  0.316908  0.395333  0.787279
# 4    0.068904  0.223079  0.538056  0.047428  0.583037
# 5    0.395617  0.732171  0.546427  0.558571  0.329132
# ..        ...       ...       ...       ...       ...
# 329  0.303704  0.042306  0.354418  0.747414  0.309633
# 330  0.325176  0.619976  0.267919  0.103217  0.031351
# 331  0.367693  0.106144  0.757074  0.160146  0.887906
# 332  0.338221  0.801101  0.226089  0.316483  0.843311
# 333  0.245002  0.398008  0.877605  0.193264  0.137597
#
# [333 rows x 5 columns]

# %%
df.drop(['A', 'D'], axis=1)
# Out:
#             B         C         E
# 0    0.878973  0.629611  0.158220
# 1    0.315828  0.417478  0.525057
# 2    0.240157  0.139917  0.619240
# 3    0.515872  0.316908  0.787279
# 4    0.223079  0.538056  0.583037
# ..        ...       ...       ...
# 329  0.042306  0.354418  0.309633
# 330  0.619976  0.267919  0.031351
# 331  0.106144  0.757074  0.887906
# 332  0.801101  0.226089  0.843311
# 333  0.398008  0.877605  0.137597
#
# [334 rows x 3 columns]

# %%
df3 = pd.read_csv("pokemon.csv.txt")

# %%
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df3.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df3.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df3.columns
# Out:
# Index(['#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary'], dtype='object')

# %%
df3.iloc[2]
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# Total              525
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
df3.iloc[1:2]
# Out:
#    #     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1  2  Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary
# 1     60           1      False

# %%
df3.sort_index(axis=0, ascending=False)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 799  721              Volcanion     Fire   Water    600  80     110      120
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 4      4             Charmander     Fire     NaN    309  39      52       43
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
#
# ...

# %%
df3.loc[df3['Type 1'] == "Fire"]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
df3.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df3.sort_values(['Type 1', 'HP'], ascending=True)
# Out:
#        #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja    Bug   Ghost    236    1      90       45       30
# 230  213    Shuckle    Bug    Rock    505   20      10      230       10
# 462  415     Combee    Bug  Flying    244   30      30       42       30
# 603  543   Venipede    Bug  Poison    260   30      45       59       30
# 314  290    Nincada    Bug  Ground    266   31      45       90       30
# ..   ...        ...    ...     ...    ...  ...     ...      ...      ...
# 142  131     Lapras  Water     Ice    535  130      85       80       85
# 145  134   Vaporeon  Water     NaN    525  130      65       60      110
# 350  320    Wailmer  Water     NaN    400  130      70       35       70
# 655  594  Alomomola  Water     NaN    470  165      75       80       40
# 351  321    Wailord  Water     NaN    500  170      90       45       90
#
#      Sp. Def  Speed  Generation  Legendary
# 316       30     40           3      False
# ...

# %%
df3.sort_values(['Type 1', 'HP'], ascending=False)
# Out:
#        #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 351  321    Wailord  Water     NaN    500  170      90       45       90
# 655  594  Alomomola  Water     NaN    470  165      75       80       40
# 142  131     Lapras  Water     Ice    535  130      85       80       85
# 145  134   Vaporeon  Water     NaN    525  130      65       60      110
# 350  320    Wailmer  Water     NaN    400  130      70       35       70
# ..   ...        ...    ...     ...    ...  ...     ...      ...      ...
# 314  290    Nincada    Bug  Ground    266   31      45       90       30
# 462  415     Combee    Bug  Flying    244   30      30       42       30
# 603  543   Venipede    Bug  Poison    260   30      45       59       30
# 230  213    Shuckle    Bug    Rock    505   20      10      230       10
# 316  292   Shedinja    Bug   Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# 351       45     60           3      False
# ...

# %%
df3['Total'] = df3['HP'] + df3['Attack'] + df3['Sp. Atk'] + df3['Sp. Def'] + df3['Speed']

# %%
df3.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    269  45      49       49
# 1  2                Ivysaur  Grass  Poison    342  60      62       63
# 2  3               Venusaur  Grass  Poison    442  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    502  80     100      123
# 4  4             Charmander   Fire     NaN    266  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df3.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df3.iloc[:,4:10].sum(axis=1)
# Out:
# 0       542
# 1       687
# 2       887
# 3      1047
# 4       510
#        ...
# 795    1000
# 796    1180
# 797    1070
# 798    1220
# 799    1010
# Length: 800, dtype: int64

# %%
df3.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    269  45      49       49
# 1  2                Ivysaur  Grass  Poison    342  60      62       63
# 2  3               Venusaur  Grass  Poison    442  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    502  80     100      123
# 4  4             Charmander   Fire     NaN    266  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df3.to_csv("modified.txt", index=False, sep='\t')

# %% [markdown]
# # filtering Data

# %%
df3.loc[df3['Type 1'] == "Grass"]
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    269   45      49       49
# 1      2                Ivysaur  Grass    Poison    342   60      62       63
# 2      3               Venusaur  Grass    Poison    442   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    502   80     100      123
# 48    43                 Oddish  Grass    Poison    265   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    248   56      61       65
# 719  651              Quilladin  Grass       NaN    310   61      78       95
# 720  652             Chesnaught  Grass  Fighting    408   88     107      122
# 740  672                 Skiddo  Grass       NaN    302   66      65       48
# 741  673                 Gogoat  Grass       NaN    469  123     100       62
#
# ...

# %%
df3.loc[(df3['Type 1'] == "Grass") & (df3['Type 2'] == "Poison")]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    269   45      49       49
# 1      2                Ivysaur  Grass  Poison    342   60      62       63
# 2      3               Venusaur  Grass  Poison    442   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    502   80     100      123
# 48    43                 Oddish  Grass  Poison    265   45      50       55
# 49    44                  Gloom  Grass  Poison    325   60      65       70
# 50    45              Vileplume  Grass  Poison    405   75      80       85
# 75    69             Bellsprout  Grass  Poison    265   50      75       35
# 76    70             Weepinbell  Grass  Poison    340   65      90       50
# 77    71             Victreebel  Grass  Poison    425   80     105       65
# 344  315                Roselia  Grass  Poison    355   50      60       45
# ...

# %%
df3.loc[(df3['Type 1'] == "Grass") & (df3['Type 2'] == "Poison") & (df3['HP']> 70)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Poison    442   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    502   80     100      123
# 50    45              Vileplume  Grass  Poison    405   75      80       85
# 77    71             Victreebel  Grass  Poison    425   80     105       65
# 652  591              Amoonguss  Grass  Poison    394  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 50       110       90     50           1      False
# 77       100       70     70           1      False
# 652       85       80     30           5      False

# %%
df3.reset_index()
# Out:
#    index    #                   Name Type 1  Type 2  Total   HP  Attack  \
# 0      0    3               Venusaur  Grass  Poison    442   80      82
# 1      1    3  VenusaurMega Venusaur  Grass  Poison    502   80     100
# 2      2   45              Vileplume  Grass  Poison    405   75      80
# 3      3   71             Victreebel  Grass  Poison    425   80     105
# 4      4  591              Amoonguss  Grass  Poison    394  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       83      100      100     80           1      False
# 1      123      122      120     80           1      False
# 2       85      110       90     50           1      False
# 3       65      100       70     70           1      False
# 4       70       85       80     30           5      False

# %%
df3.reset_index(drop=True, inplace=True)

# %%
df3
# Out:
#      #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    442   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    502   80     100      123
# 2   45              Vileplume  Grass  Poison    405   75      80       85
# 3   71             Victreebel  Grass  Poison    425   80     105       65
# 4  591              Amoonguss  Grass  Poison    394  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
df3.loc[df3['Name'].str.contains('Mega')]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  3  VenusaurMega Venusaur  Grass  Poison    502  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1      122      120     80           1      False

# %%
df3 = pd.read_csv("pokemon.csv.txt")

# %%
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df3.loc[df3['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
df3.loc[df3['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

# %%
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   flamer   Water    600  80     110      120
#
# ...

# %%
df3.loc[df3['Type 1'] == 'flamer', 'Legendary'] = True

# %%
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander   flamer     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion   flamer   Water    600  80     110      120
#
# ...

# %%
df3 = pd.read_csv("pokemon.csv.txt")
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df3.loc[df3['Total'] > 500, ['Generation', 'Legendary']] = 'Test value'

# %%
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df3.loc[df3['Total'] > 500, ['Generation', 'Legendary']] = ['Test 1', 'Test 2']

# %%
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # Aggregate Value (grouping by)

# %%
df3 = pd.read_csv("pokemon.csv.txt")
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df3.groupby(['Type 1']).mean()
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
df3.groupby(['Type 1']).mean().sort_values('Defense')
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# ...

# %%
df3.groupby(['Type 1']).mean().sort_values('Defense', ascending= False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# ...

# %%
df3.groupby(['Type 1']).sum()
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       23080  26146  3925    4897     4880     3717     4471   4256
# Dark      14302  13818  2071    2740     2177     2314     2155   2361
# Dragon    15180  17617  2666    3588     2764     3099     2843   2657
# Electric  15994  19510  2631    3040     2917     3961     3243   3718
# Fairy      7642   7024  1260    1046     1117     1335     1440    826
# Fighting   9824  11244  1886    2613     1780     1434     1747   1784
# Fire      17025  23820  3635    4408     3524     4627     3755   3871
# Flying     2711   1940   283     315      265      377      290    410
# Ghost     15568  14066  2062    2361     2598     2539     2447   2059
# Grass     24141  29480  4709    5125     4956     5425     4930   4335
# Ground    11401  14000  2361    3064     2715     1807     2008   2045
# Ice       10165  10403  1728    1746     1714     1861     1831   1523
# ...

# %%
df3.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
df3['count'] = 1
df3
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df3.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64
